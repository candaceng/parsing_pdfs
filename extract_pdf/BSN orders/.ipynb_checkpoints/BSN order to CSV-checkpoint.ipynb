# %% [markdown]
# ## Parsing a BSN Sports PDF <br/>
# **Libraries you will need**
# - **pdfplumber**: opens pdfs and allows them to be parsed page by page
# - **re**: finds patterns in text to know where to find specific data (e.g. dates, model numbers, etc.)
# - **pandas**: used here for creating a data frame for exporting to a csv
# - **glob**: allows for iterating through files ending in .pdf
# <br/><br/>
# **Note**: Make sure your pdfs are stored in the *put_pdfs_here* folder

# %%
import pdfplumber
import re
import pandas as pd
import glob

from collections import namedtuple

# %%
Line = namedtuple('Line', 'sport_id order_date order_ref_number item_description item_category item_size qty_ordered chart item_unit item_pref_vendor item_manuf item_manuf_model item_price item_serial item_expendable item_universal')

# %% [markdown]
# **Regular Expressions**<br/>
# The code below might look confusing at first but it is very useful to look for patterns in text. You can learn more about regular expressions here: https://www.w3schools.com/python/python_regex.asp

# %%
manuf_model_re = re.compile(r'Item # - (.*)')
quantities_re = re.compile(r'\s*(\d*) ([A-Z]{2})\D*(\d*\.?\d*)')

# %%
lines = []
check_des = False 
check_info = False
check_sizes = False
check_qty = False

for file in glob.iglob("put_pdfs_here/*pdf"):
    with pdfplumber.open(file) as pdf:
        pages = pdf.pages
        for page in pdf.pages:
            text = page.extract_text()
            #print(text)
            for line in text.split("\n"):
                
                # regular expressions - used for identifying patterns in text
                model_num = manuf_model_re.search(line)
                
                # Order Date
                if line.startswith('Order Date'):
                    order_date = re.compile(r'(\d{2}/\d{2}/\d{4})').search(line).group(1)
                
                # Order Reference Number
                elif line.startswith('Cart Name'):
                    ref_num = re.compile(r'Cart Name:(.*)').search(line).group(1)
                
                # A line starting with 'Item description' signals the beginning of the items
                elif line.startswith('Item Description'):
                    check_des = True
                
                # Item Description
                elif check_des: 
                    if line.startswith('Page:') or line.startswith('Subtotal'):
                        check_des = False
                        break
                    item_description = line 
                    check_des = False
                    check_info = True
                    
                # Quantity and Price
                elif check_info:
                    info = quantities_re.search(line)
                    qty = info.group(1)
                    item_unit = "Each" if info.group(2) == "EA" else "Pair"
                    price = info.group(3)
                    check_info = False
                    
                # Manufacture Model
                elif model_num:
                    manuf_model = model_num.group(1)
                    #lines.append(Line("", order_date, ref_num, item_description, "", "", qty, "", "Each", "", "", manuf_model, price, "N", "Y", "N"))
                    check_sizes = True
                    
                # Sizes
                elif check_sizes:
                    # A line starting with "Subtotal" signals the end of items
                    if line.startswith('Subtotal'):
                        lines.append(Line("", order_date, ref_num, item_description, "", "", qty, "", item_unit, "", "BSN", manuf_model, price, "N", "Y", "N"))
                        break 
                    else:
                        sizes = line.split()
                    check_sizes = False
                    check_qty = True 
                
                # Quantities per size
                elif check_qty:
                    qtys = re.findall(r'\d+', line)
                    for i in range(len(qtys)):
                        lines.append(Line("", order_date, ref_num, item_description, "", sizes[i], qtys[i], "", item_unit, "", "BSN", manuf_model, price, "N", "Y", "N"))
                    check_qty = False
                    check_des = True
# Out:
#       1 EA $      52.00  $      52.00
#       1 EA $      52.00  $      52.00
#      34 PR $      53.63  $   1,823.42
#       6 PR $      53.63  $     321.78
#       4 EA $      22.50  $      90.00
#       3 EA $      65.00  $     195.00
#      28 EA $      22.50  $     630.00
#      28 EA $      17.50  $     490.00
#       2 EA $      20.00  $      40.00

# %%
df = pd.DataFrame(lines)
df
# Out:
#    sport_id  order_date           order_ref_number  \
# 0            05/09/2019  VB 2/M Fill Ins #17
# 1            05/09/2019  VB 2/M Fill Ins #17
# 2            06/27/2019  VB Team #2
# 3            06/27/2019  VB Team #2
# 4            06/27/2019  VB Team #2
# 5            06/27/2019  VB Team #2
# 6            06/27/2019  VB Team #2
# 7            06/27/2019  VB Team #2
# 8            06/27/2019  VB Team #2
# 9            06/27/2019  VB Team #2
# 10           06/27/2019  VB Team #2
# 11           06/27/2019  VB Team #2
# 12           06/27/2019  VB Team #2
# 13           06/27/2019  VB Team #2
# 14           06/27/2019  VB Team #2
# 15           06/27/2019  VB Team #2
# 16           06/27/2019  VB Team #2
# 17           06/27/2019  VB Team #2
# 18           06/27/2019  VB Team #2
# 19           06/27/2019  VB Team #2
# 20           06/27/2019  VB Team #2
# 21           06/27/2019  VB Team #2
# 22           06/27/2019  VB Team #2
# 23           06/27/2019  VB Team #2
# 24           06/27/2019  VB Team #2
# 25           06/27/2019  VB Team #2
# 26           06/27/2019  VB Team #2
#
#                                  item_description item_category item_size  \
# 0   SUBLIM - NO CUST LOGO-WOMENS DIGITAL SPEED ST                     MED
# 1   SUBLIM - NO CUST LOGO-WOMENS DIGITAL SPEED ST                     MED
# 2   001 - BLK/WHT-MAMBA FOCUS SHOES                                     8
# 3   001 - BLK/WHT-MAMBA FOCUS SHOES                                   8.5
# 4   001 - BLK/WHT-MAMBA FOCUS SHOES                                     9
# 5   001 - BLK/WHT-MAMBA FOCUS SHOES                                   9.5
# 6   001 - BLK/WHT-MAMBA FOCUS SHOES                                    10
# 7   001 - BLK/WHT-MAMBA FOCUS SHOES                                  10.5
# 8   001 - BLK/WHT-MAMBA FOCUS SHOES                                    11
# 9   001 - BLK/WHT-MAMBA FOCUS SHOES                                  12.5
# 10  001 - BLK/WHT-MAMBA FOCUS SHOES                                     7
# 11  001 - BLK/WHT-MAMBA FOCUS SHOES                                   7.5
# 12  065 - COOL GRY-CLASSIC LONG SLEEVE MESH TOP                       MED
# 13  065 - COOL GRY-CLASSIC LONG SLEEVE MESH TOP                       LRG
# 14  065 - COOL GRY-CLASSIC LONG SLEEVE MESH TOP                       XLG
# 15  010 - BLACK-THERMAFLEX FZ SHOWTIME HOODY                          LRG
# 16  010 - BLACK-THERMAFLEX FZ SHOWTIME HOODY                          XLG
# 17  012 - WOLF GRY-HYPER DRY LONG SLEEVE BREATHE                      SML
# 18  012 - WOLF GRY-HYPER DRY LONG SLEEVE BREATHE                      MED
# 19  012 - WOLF GRY-HYPER DRY LONG SLEEVE BREATHE                      LRG
# 20  012 - WOLF GRY-HYPER DRY LONG SLEEVE BREATHE                      XLG
# 21  012 - WOLF GRY-HYPER DRY SHORT SLEEVE BREATHE                     SML
# 22  012 - WOLF GRY-HYPER DRY SHORT SLEEVE BREATHE                     MED
# 23  012 - WOLF GRY-HYPER DRY SHORT SLEEVE BREATHE                     LRG
# 24  012 - WOLF GRY-HYPER DRY SHORT SLEEVE BREATHE                     XLG
# 25  060 - ANTHRACT-WOMENS LEGEND VENEER LS HOODIE                     LRG
# 26  060 - ANTHRACT-WOMENS LEGEND VENEER LS HOODIE                     XLG
#
#    qty_ordered chart item_unit item_pref_vendor item_manuf item_manuf_model  \
# 0            1            Each                                   NK658068
# 1            1            Each                                   NK658068
# 2            2            Pair                                   NKAT1214
# 3            6            Pair                                   NKAT1214
# 4            4            Pair                                   NKAT1214
# 5            8            Pair                                   NKAT1214
# 6            4            Pair                                   NKAT1214
# 7            6            Pair                                   NKAT1214
# 8            2            Pair                                   NKAT1214
# 9            2            Pair                                   NKAT1214
# 10           4            Pair                                   NKAT1214
# 11           2            Pair                                   NKAT1214
# 12           1            Each                                   NKCI4766
# 13           1            Each                                   NKCI4766
# 14           2            Each                                   NKCI4766
# 15           1            Each                                   NKAT5347
# 16           2            Each                                   NKAT5347
# 17          12            Each                                   NKAO7579
# 18          10            Each                                   NKAO7579
# 19           3            Each                                   NKAO7579
# 20           3            Each                                   NKAO7579
# 21          12            Each                                   NKAO7580
# 22          10            Each                                   NKAO7580
# 23           3            Each                                   NKAO7580
# 24           3            Each                                   NKAO7580
# 25           1            Each                                   NKAQ3504
# 26           1            Each                                   NKAQ3504
#
#    item_price item_serial item_expendable item_universal
# 0       52.00           N               Y              N
# 1       52.00           N               Y              N
# 2       53.63           N               Y              N
# 3       53.63           N               Y              N
# 4       53.63           N               Y              N
# 5       53.63           N               Y              N
# 6       53.63           N               Y              N
# 7       53.63           N               Y              N
# 8       53.63           N               Y              N
# 9       53.63           N               Y              N
# 10      53.63           N               Y              N
# 11      53.63           N               Y              N
# 12      22.50           N               Y              N
# 13      22.50           N               Y              N
# 14      22.50           N               Y              N
# 15      65.00           N               Y              N
# 16      65.00           N               Y              N
# 17      22.50           N               Y              N
# 18      22.50           N               Y              N
# 19      22.50           N               Y              N
# 20      22.50           N               Y              N
# 21      17.50           N               Y              N
# 22      17.50           N               Y              N
# 23      17.50           N               Y              N
# 24      17.50           N               Y              N
# 25      20.00           N               Y              N
# 26      20.00           N               Y              N

# %%
df.to_csv('formatted.csv', index=False)
